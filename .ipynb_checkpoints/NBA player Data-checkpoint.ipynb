# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (1.1.9)
# Requirement already satisfied: requests in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (from nba_api) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/markomiholjcic/Downloads/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (1.25.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import nba_api.stats
import json
import pandas as pd
import numpy as np

# %%
#from nba_api.stats.endpoints import shotchartdetail

#response = shotchartdetail.ShotChartDetail(
#    context_measure_simple = 'FGA',
#    team_id=0,
#    player_id=977,
#    season_nullable='1996-97',
#    season_type_all_star='Regular Season'
#)

# %%
from nba_api.stats.endpoints import shotchartdetail

df = pd.DataFrame()

for season in range(1996,2016):
    seasonString = str(season) + '-' + str(season+1)[2:]
    
    response = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=977,
    season_nullable= seasonString ,
    season_type_all_star='Regular Season')
    
    content = json.loads(response.get_json())
    
    headers = content['resultSets'][0]['headers']
    
    shots = content['resultSets'][0]['rowSet']
    
    shots_df = pd.DataFrame(shots, columns=headers)
    
    array = np.full((shots_df.shape[0],1),"Regular")

    shots_df["Season"] = array
    
    response2 = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=977,
    season_nullable= seasonString ,
    season_type_all_star='Playoffs')
    
    content2 = json.loads(response2.get_json())
    
    headers2 = content2['resultSets'][0]['headers']
    
    shots2 = content2['resultSets'][0]['rowSet']
    
    shots_df2 = pd.DataFrame(shots2, columns = headers2)
    
    array2 = np.full((shots_df2.shape[0],1), "Playoffs")
    
    shots_df2["Season"] = array2

    df = df.append(shots_df, ignore_index = True)
    
    df = df.append(shots_df2, ignore_index = True)
    
df
# Out:
#                GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID  PLAYER_NAME  \
# 0      Shot Chart Detail  0029600027           102       977  Kobe Bryant
# 1      Shot Chart Detail  0029600031           127       977  Kobe Bryant
# 2      Shot Chart Detail  0029600044           124       977  Kobe Bryant
# 3      Shot Chart Detail  0029600044           144       977  Kobe Bryant
# 4      Shot Chart Detail  0029600044           151       977  Kobe Bryant
# ...                  ...         ...           ...       ...          ...
# 30692  Shot Chart Detail  0021501228           462       977  Kobe Bryant
# 30693  Shot Chart Detail  0021501228           475       977  Kobe Bryant
# 30694  Shot Chart Detail  0021501228           479       977  Kobe Bryant
# 30695  Shot Chart Detail  0021501228           482       977  Kobe Bryant
# 30696  Shot Chart Detail  0021501228           488       977  Kobe Bryant
#
#           TEAM_ID           TEAM_NAME PERIOD MINUTES_REMAINING  \
# 0      1610612747  Los Angeles Lakers      1                 0
# 1      1610612747  Los Angeles Lakers      2                10
# 2      1610612747  Los Angeles Lakers      2                 8
# 3      1610612747  Los Angeles Lakers      2                 6
# 4      1610612747  Los Angeles Lakers      2                 5
# ...           ...                 ...    ...               ...
# 30692  1610612747  Los Angeles Lakers      4                 3
# 30693  1610612747  Los Angeles Lakers      4                 1
# 30694  1610612747  Los Angeles Lakers      4                 1
# 30695  1610612747  Los Angeles Lakers      4                 0
# 30696  1610612747  Los Angeles Lakers      4                 0
#
#       SECONDS_REMAINING  ...  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0                    42  ...        16-24 ft.            18  -140   116
# 1                     8  ...        16-24 ft.            16  -131    97
# 2                    37  ...        16-24 ft.            23  -142   181
# 3                    34  ...  Less Than 8 ft.             0     0     0
# 4                    27  ...         8-16 ft.            13   -10   138
# ...                 ...  ...              ...           ...   ...   ...
# 30692                 5  ...  Less Than 8 ft.             0     6    -6
# 30693                45  ...  Less Than 8 ft.             0    -7     2
# 30694                27  ...         8-16 ft.            14    69   129
# 30695                59  ...          24+ ft.            25  -232   110
# 30696                31  ...        16-24 ft.            19    58   188
#
#       SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG GAME_DATE  HTM  VTM   Season
# 0                       1              0  19961103  LAL  MIN  Regular
# 1                       1              0  19961105  NYK  LAL  Regular
# 2                       1              1  19961106  CHH  LAL  Regular
# 3                       1              0  19961106  CHH  LAL  Regular
# 4                       1              1  19961106  CHH  LAL  Regular
# ...                   ...            ...       ...  ...  ...      ...
# 30692                   1              1  20160413  LAL  UTA  Regular
# 30693                   1              1  20160413  LAL  UTA  Regular
# 30694                   1              1  20160413  LAL  UTA  Regular
# 30695                   1              1  20160413  LAL  UTA  Regular
# 30696                   1              1  20160413  LAL  UTA  Regular
#
# [30697 rows x 25 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Kobedata.csv', index = False)

# %%
df.to_json('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Kobedata.json')

# %%
from nba_api.stats.endpoints import shotchartdetail

df = pd.DataFrame()

for season in range(2009,2020):
    seasonString = str(season) + '-' + str(season+1)[2:]
    
    response = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=201939,
    season_nullable= seasonString ,
    season_type_all_star='Regular Season')
    
    content = json.loads(response.get_json())
    
    headers = content['resultSets'][0]['headers']
    
    shots = content['resultSets'][0]['rowSet']
    
    shots_df = pd.DataFrame(shots, columns=headers)
    
    response2 = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=201939,
    season_nullable= seasonString ,
    season_type_all_star='Playoffs')
    
    content2 = json.loads(response2.get_json())
    
    headers2 = content2['resultSets'][0]['headers']
    
    shots2 = content2['resultSets'][0]['rowSet']
    
    shots_df2 = pd.DataFrame(shots2, columns = headers2)

    df = df.append(shots_df, ignore_index = True)
    
    df = df.append(shots_df2, ignore_index = True)

df
# Out:
#                GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID    PLAYER_NAME  \
# 0      Shot Chart Detail  0020900015             4    201939  Stephen Curry
# 1      Shot Chart Detail  0020900015            17    201939  Stephen Curry
# 2      Shot Chart Detail  0020900015            53    201939  Stephen Curry
# 3      Shot Chart Detail  0020900015           141    201939  Stephen Curry
# 4      Shot Chart Detail  0020900015           249    201939  Stephen Curry
# ...                  ...         ...           ...       ...            ...
# 14097  Shot Chart Detail  0021900929           398    201939  Stephen Curry
# 14098  Shot Chart Detail  0021900929           562    201939  Stephen Curry
# 14099  Shot Chart Detail  0021900929           670    201939  Stephen Curry
# 14100  Shot Chart Detail  0021900929           686    201939  Stephen Curry
# 14101  Shot Chart Detail  0021900929           729    201939  Stephen Curry
#
#           TEAM_ID              TEAM_NAME PERIOD MINUTES_REMAINING  \
# 0      1610612744  Golden State Warriors      1                11
# 1      1610612744  Golden State Warriors      1                 9
# 2      1610612744  Golden State Warriors      1                 6
# 3      1610612744  Golden State Warriors      2                 9
# 4      1610612744  Golden State Warriors      2                 2
# ...           ...                    ...    ...               ...
# 14097  1610612744  Golden State Warriors      3                 7
# 14098  1610612744  Golden State Warriors      4                 8
# 14099  1610612744  Golden State Warriors      4                 2
# 14100  1610612744  Golden State Warriors      4                 0
# 14101  1610612744  Golden State Warriors      4                 0
#
#       SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                    25  ...  Right Side Center(RC)          24+ ft.
# 1                    31  ...   Left Side Center(LC)        16-24 ft.
# 2                     2  ...              Center(C)         8-16 ft.
# 3                    49  ...           Left Side(L)        16-24 ft.
# 4                    19  ...   Left Side Center(LC)        16-24 ft.
# ...                 ...  ...                    ...              ...
# 14097                16  ...  Right Side Center(RC)          24+ ft.
# 14098                16  ...              Center(C)          24+ ft.
# 14099                 0  ...              Center(C)  Less Than 8 ft.
# 14100                39  ...  Right Side Center(RC)          24+ ft.
# 14101                10  ...   Left Side Center(LC)          24+ ft.
#
#       SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG GAME_DATE  \
# 0                26    99   249                   1              0  20091028
# 1                18  -122   145                   1              1  20091028
# 2                14   -60   129                   1              0  20091028
# 3                19  -172    82                   1              0  20091028
# 4                16   -68   148                   1              0  20091028
# ...             ...   ...   ...                 ...            ...       ...
# 14097            30   112   288                   1              1  20200305
# 14098            27    20   273                   1              0  20200305
# 14099             2    -5    20                   1              1  20200305
# 14100            32   149   293                   1              0  20200305
# 14101            25  -100   236                   1              0  20200305
#
#        HTM  VTM
# 0      GSW  HOU
# 1      GSW  HOU
# 2      GSW  HOU
# 3      GSW  HOU
# 4      GSW  HOU
# ...    ...  ...
# 14097  GSW  TOR
# 14098  GSW  TOR
# 14099  GSW  TOR
# 14100  GSW  TOR
# 14101  GSW  TOR
#
# [14102 rows x 24 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Currydata.csv', index = False)

# %%
df.to_json('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Currydata.json')

# %%
from nba_api.stats.endpoints import shotchartdetail

df = pd.DataFrame()

for season in range(2009,2020):
    seasonString = str(season) + '-' + str(season+1)[2:]
    
    response = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=201935,
    season_nullable= seasonString ,
    season_type_all_star='Regular Season')
    
    content = json.loads(response.get_json())
    
    headers = content['resultSets'][0]['headers']
    
    shots = content['resultSets'][0]['rowSet']
    
    shots_df = pd.DataFrame(shots, columns=headers)
    
    response2 = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=201935,
    season_nullable= seasonString ,
    season_type_all_star='Playoffs')
    
    content2 = json.loads(response2.get_json())
    
    headers2 = content2['resultSets'][0]['headers']
    
    shots2 = content2['resultSets'][0]['rowSet']
    
    shots_df2 = pd.DataFrame(shots2, columns = headers2)

    df = df.append(shots_df, ignore_index = True)
    
    df = df.append(shots_df2, ignore_index = True)

df
# Out:
#                GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0      Shot Chart Detail  0020900012            126     201935  James Harden
# 1      Shot Chart Detail  0020900012            405     201935  James Harden
# 2      Shot Chart Detail  0020900023             85     201935  James Harden
# 3      Shot Chart Detail  0020900023             94     201935  James Harden
# 4      Shot Chart Detail  0020900023            136     201935  James Harden
# ...                  ...         ...            ...        ...           ...
# 16039  Shot Chart Detail  0041900225            449     201935  James Harden
# 16040  Shot Chart Detail  0041900225            497     201935  James Harden
# 16041  Shot Chart Detail  0041900225            511     201935  James Harden
# 16042  Shot Chart Detail  0041900225            559     201935  James Harden
# 16043  Shot Chart Detail  0041900225            561     201935  James Harden
#
#           TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0      1610612760  Oklahoma City Thunder       2                 11
# 1      1610612760  Oklahoma City Thunder       4                 10
# 2      1610612760  Oklahoma City Thunder       1                  1
# 3      1610612760  Oklahoma City Thunder       1                  0
# 4      1610612760  Oklahoma City Thunder       2                 10
# ...           ...                    ...     ...                ...
# 16039  1610612745        Houston Rockets       3                  1
# 16040  1610612745        Houston Rockets       4                  9
# 16041  1610612745        Houston Rockets       4                  9
# 16042  1610612745        Houston Rockets       4                  6
# 16043  1610612745        Houston Rockets       4                  6
#
#        SECONDS_REMAINING  ...        SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                     41  ...  Left Side Center(LC)        16-24 ft.
# 1                     44  ...         Right Side(R)          24+ ft.
# 2                     17  ...          Left Side(L)        16-24 ft.
# 3                     31  ...             Center(C)        16-24 ft.
# 4                      6  ...  Left Side Center(LC)          24+ ft.
# ...                  ...  ...                   ...              ...
# 16039                 46  ...         Right Side(R)         8-16 ft.
# 16040                 55  ...  Left Side Center(LC)          24+ ft.
# 16041                 14  ...             Center(C)  Less Than 8 ft.
# 16042                 28  ...         Right Side(R)          24+ ft.
# 16043                 20  ...             Center(C)  Less Than 8 ft.
#
#       SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  \
# 0                19  -155   116                   1               1
# 1                22   226    22                   1               1
# 2                17  -175     9                   1               0
# 3                20   -46   195                   1               0
# 4                27  -224   153                   1               0
# ...             ...   ...   ...                 ...             ...
# 16039             9    95     5                   1               1
# 16040            26  -168   200                   1               0
# 16041             1   -11     2                   1               1
# 16042            22   225    43                   1               0
# 16043             1   -11    -1                   1               0
#
#        GAME_DATE  HTM  VTM
# 0       20091028  OKC  SAC
# 1       20091028  OKC  SAC
# 2       20091030  DET  OKC
# 3       20091030  DET  OKC
# 4       20091030  DET  OKC
# ...          ...  ...  ...
# 16039   20200912  LAL  HOU
# 16040   20200912  LAL  HOU
# 16041   20200912  LAL  HOU
# 16042   20200912  LAL  HOU
# 16043   20200912  LAL  HOU
#
# [16044 rows x 24 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Hardendata.csv', index = False)

# %%
df.to_json('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Hardendata.json')

# %%
from nba_api.stats.endpoints import shotchartdetail

df = pd.DataFrame()

for season in range(2018,2020):
    seasonString = str(season) + '-' + str(season+1)[2:]
    
    response = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=1629029,
    season_nullable= seasonString ,
    season_type_all_star='Regular Season')
    
    content = json.loads(response.get_json())
    
    headers = content['resultSets'][0]['headers']
    
    shots = content['resultSets'][0]['rowSet']
    
    shots_df = pd.DataFrame(shots, columns=headers)
    
    response2 = shotchartdetail.ShotChartDetail(
    context_measure_simple = 'FGA',
    team_id=0,
    player_id=1629029,
    season_nullable= seasonString ,
    season_type_all_star='Playoffs')
    
    content2 = json.loads(response2.get_json())
    
    headers2 = content2['resultSets'][0]['headers']
    
    shots2 = content2['resultSets'][0]['rowSet']
    
    shots_df2 = pd.DataFrame(shots2, columns = headers2)

    df = df.append(shots_df, ignore_index = True)
    
    df = df.append(shots_df2, ignore_index = True)

df
# Out:
#               GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID  PLAYER_NAME  \
# 0     Shot Chart Detail  0021800013            23   1629029  Luka Doncic
# 1     Shot Chart Detail  0021800013            31   1629029  Luka Doncic
# 2     Shot Chart Detail  0021800013            38   1629029  Luka Doncic
# 3     Shot Chart Detail  0021800013            46   1629029  Luka Doncic
# 4     Shot Chart Detail  0021800013            80   1629029  Luka Doncic
# ...                 ...         ...           ...       ...          ...
# 2564  Shot Chart Detail  0041900156           544   1629029  Luka Doncic
# 2565  Shot Chart Detail  0041900156           546   1629029  Luka Doncic
# 2566  Shot Chart Detail  0041900156           565   1629029  Luka Doncic
# 2567  Shot Chart Detail  0041900156           569   1629029  Luka Doncic
# 2568  Shot Chart Detail  0041900156           580   1629029  Luka Doncic
#
#          TEAM_ID         TEAM_NAME PERIOD MINUTES_REMAINING SECONDS_REMAINING  \
# 0     1610612742  Dallas Mavericks      1                10                39
# 1     1610612742  Dallas Mavericks      1                 9                49
# 2     1610612742  Dallas Mavericks      1                 9                21
# 3     1610612742  Dallas Mavericks      1                 8                52
# 4     1610612742  Dallas Mavericks      1                 4                48
# ...          ...               ...    ...               ...               ...
# 2564  1610612742  Dallas Mavericks      4                 6                37
# 2565  1610612742  Dallas Mavericks      4                 6                 5
# 2566  1610612742  Dallas Mavericks      4                 4                34
# 2567  1610612742  Dallas Mavericks      4                 4                 7
# 2568  1610612742  Dallas Mavericks      4                 3                 9
#
#       ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0     ...              Center(C)        16-24 ft.            20    30   204
# 1     ...              Center(C)  Less Than 8 ft.             1    -2    14
# 2     ...  Right Side Center(RC)          24+ ft.            25   122   226
# 3     ...              Center(C)  Less Than 8 ft.             1    -5    10
# 4     ...              Center(C)  Less Than 8 ft.             1     0    17
# ...   ...                    ...              ...           ...   ...   ...
# 2564  ...              Center(C)        16-24 ft.            17   -18   176
# 2565  ...              Center(C)          24+ ft.            25   -35   253
# 2566  ...          Right Side(R)         8-16 ft.            15   116   100
# 2567  ...              Center(C)  Less Than 8 ft.             1    16     3
# 2568  ...  Right Side Center(RC)        16-24 ft.            22   126   189
#
#      SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0                      1              0  20181017  PHX  DAL
# 1                      1              1  20181017  PHX  DAL
# 2                      1              0  20181017  PHX  DAL
# 3                      1              1  20181017  PHX  DAL
# 4                      1              1  20181017  PHX  DAL
# ...                  ...            ...       ...  ...  ...
# 2564                   1              1  20200830  DAL  LAC
# 2565                   1              0  20200830  DAL  LAC
# 2566                   1              0  20200830  DAL  LAC
# 2567                   1              1  20200830  DAL  LAC
# 2568                   1              0  20200830  DAL  LAC
#
# [2569 rows x 24 columns]

# %%
array = np.full((df.shape[0],1),"Regular")
array.shape

df["Season"] = array

df
# Out:
#               GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID  PLAYER_NAME  \
# 0     Shot Chart Detail  0021800013            23   1629029  Luka Doncic
# 1     Shot Chart Detail  0021800013            31   1629029  Luka Doncic
# 2     Shot Chart Detail  0021800013            38   1629029  Luka Doncic
# 3     Shot Chart Detail  0021800013            46   1629029  Luka Doncic
# 4     Shot Chart Detail  0021800013            80   1629029  Luka Doncic
# ...                 ...         ...           ...       ...          ...
# 2564  Shot Chart Detail  0041900156           544   1629029  Luka Doncic
# 2565  Shot Chart Detail  0041900156           546   1629029  Luka Doncic
# 2566  Shot Chart Detail  0041900156           565   1629029  Luka Doncic
# 2567  Shot Chart Detail  0041900156           569   1629029  Luka Doncic
# 2568  Shot Chart Detail  0041900156           580   1629029  Luka Doncic
#
#          TEAM_ID         TEAM_NAME PERIOD MINUTES_REMAINING SECONDS_REMAINING  \
# 0     1610612742  Dallas Mavericks      1                10                39
# 1     1610612742  Dallas Mavericks      1                 9                49
# 2     1610612742  Dallas Mavericks      1                 9                21
# 3     1610612742  Dallas Mavericks      1                 8                52
# 4     1610612742  Dallas Mavericks      1                 4                48
# ...          ...               ...    ...               ...               ...
# 2564  1610612742  Dallas Mavericks      4                 6                37
# 2565  1610612742  Dallas Mavericks      4                 6                 5
# 2566  1610612742  Dallas Mavericks      4                 4                34
# 2567  1610612742  Dallas Mavericks      4                 4                 7
# 2568  1610612742  Dallas Mavericks      4                 3                 9
#
#       ...  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0     ...        16-24 ft.            20    30   204                   1
# 1     ...  Less Than 8 ft.             1    -2    14                   1
# 2     ...          24+ ft.            25   122   226                   1
# 3     ...  Less Than 8 ft.             1    -5    10                   1
# 4     ...  Less Than 8 ft.             1     0    17                   1
# ...   ...              ...           ...   ...   ...                 ...
# 2564  ...        16-24 ft.            17   -18   176                   1
# 2565  ...          24+ ft.            25   -35   253                   1
# 2566  ...         8-16 ft.            15   116   100                   1
# 2567  ...  Less Than 8 ft.             1    16     3                   1
# 2568  ...        16-24 ft.            22   126   189                   1
#
#      SHOT_MADE_FLAG GAME_DATE  HTM  VTM   Season
# 0                 0  20181017  PHX  DAL  Regular
# 1                 1  20181017  PHX  DAL  Regular
# 2                 0  20181017  PHX  DAL  Regular
# 3                 1  20181017  PHX  DAL  Regular
# 4                 1  20181017  PHX  DAL  Regular
# ...             ...       ...  ...  ...      ...
# 2564              1  20200830  DAL  LAC  Regular
# 2565              0  20200830  DAL  LAC  Regular
# 2566              0  20200830  DAL  LAC  Regular
# 2567              1  20200830  DAL  LAC  Regular
# 2568              0  20200830  DAL  LAC  Regular
#
# [2569 rows x 25 columns]

# %%
df.shape
# Out:
# (2569, 24)

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Doncicdata.csv', index = False)

# %%
df.to_json('/Users/markomiholjcic/Documents/GitHub/DataVizProject/Doncicdata.json')
